# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Load the input.xlsx file into a pandas dataframe
df = pd.read_excel('input.xlsx')

# Loop through each URL in the second column
for i, row in df.iterrows():
    url = row['URL']
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract the article text
    article_text = ''
    for paragraph in soup.find_all('p'):
        article_text += paragraph.text

    # Extract the article title
    article_title = soup.find('title').text

    # Combine the article title and text
    article = article_title + '\n' + article_text

    # Save the article text to a file with the URL_ID as its file name
    with open(str(i) + '.txt', 'w', encoding='utf-8') as file:
        file.write(article)
        print(f"Saved article text for URL {url} to file {str(i)}.txt")
# Out:
# Saved article text for URL https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/ to file 0.txt
# Saved article text for URL https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/ to file 1.txt
# Saved article text for URL https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/ to file 2.txt
# Saved article text for URL https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/ to file 3.txt
# Saved article text for URL https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/ to file 4.txt
# Saved article text for URL https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/ to file 5.txt
# Saved article text for URL https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/ to file 6.txt
# ...
